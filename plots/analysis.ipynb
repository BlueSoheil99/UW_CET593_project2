# %%
import pandas as pd
import plots

# %%
df = pd.read_csv('../Results/default_normal.csv')

# %%
# df.columns

# %%
focus_cols_list = ['waiting_time', 'queue_length', 'fuel_consumption']
main_cols_list = ['ped_phasing', 'control_type', 'penetration']
df_focus = df[main_cols_list + focus_cols_list]

# %%
df_focus.groupby(by=['ped_phasing', 'control_type']).mean()
# Out:
#                           penetration  waiting_time  queue_length  \
# ped_phasing control_type
# Concurrent  actuated            0.625     56.751590     11.289089
#             fixed_time          0.625     64.563046     12.352668
#             multi_scale         0.625     37.218407      8.445268
# Exclusive   actuated            0.625    546.028562     32.763241
#             fixed_time          0.625    106.589457     16.647831
#             multi_scale         0.625     56.817848     10.123413
#
#                           fuel_consumption
# ped_phasing control_type
# Concurrent  actuated             90.027673
#             fixed_time           89.780198
#             multi_scale          55.381568
# Exclusive   actuated            206.254765
#             fixed_time          102.150623
#             multi_scale          62.354434

# %%
df_focus[['waiting_time', 'queue_length', 'fuel_consumption', 'penetration', 'control_type']].groupby(by=['penetration', 'control_type']).mean()
# Out:
#                           waiting_time  queue_length  fuel_consumption
# penetration control_type
# 0.2         actuated        635.672131     22.026165        147.142242
#             fixed_time      180.491803     14.500249         95.864193
#             multi_scale     111.274590     10.190551         60.364362
# 0.5         actuated        256.794702     22.026165        150.941655
#             fixed_time       72.913907     14.500249         96.126418
#             multi_scale      37.279801      9.706854         59.445683
# 0.8         actuated        171.575221     22.026165        147.149992
#             fixed_time       48.716814     14.500249         95.117093
#             multi_scale      22.790929      8.814156         58.258918
# 1.0         actuated        141.518248     22.026165        147.330988
#             fixed_time       40.182482     14.500249         96.753938
#             multi_scale      16.727190      8.425801         57.403042

# %%
df_uw_normal = pd.read_csv('../Results/UW_normal.csv')
df_focus_uw_normal = df_uw_normal[main_cols_list + focus_cols_list]

# %%
df_focus_uw_normal.groupby(by=['ped_phasing', 'control_type']).mean()
# Out:
#                           penetration  waiting_time  queue_length  \
# ped_phasing control_type
# Concurrent  actuated            0.625      7.413793      5.743184
#             fixed_time          0.625     13.150862      7.681239
#             multi_scale         0.625      9.223060      7.488755
# Exclusive   actuated            0.625     17.745690      7.787787
#             fixed_time          0.625     22.232759      8.832007
#             multi_scale         0.625     13.656250      7.878641
#
#                           fuel_consumption
# ped_phasing control_type
# Concurrent  actuated             60.305950
#             fixed_time           59.480104
#             multi_scale          50.985380
# Exclusive   actuated             67.825046
#             fixed_time           66.511883
#             multi_scale          53.247568

# %%
df_focus_uw_normal[['waiting_time', 'queue_length', 'fuel_consumption', 'penetration', 'control_type']].groupby(by=['penetration', 'control_type']).mean()
# Out:
#                           waiting_time  queue_length  fuel_consumption
# penetration control_type
# 0.2         actuated         12.579741      6.765486         64.714813
#             fixed_time       17.691810      8.256623         61.175360
#             multi_scale      13.051724      8.134367         52.925741
# 0.5         actuated         12.579741      6.765486         63.430764
#             fixed_time       17.691810      8.256623         63.009735
#             multi_scale      10.495690      8.247757         50.742526
# 0.8         actuated         12.579741      6.765486         63.281237
#             fixed_time       17.691810      8.256623         63.622229
#             multi_scale      11.508621      7.657645         52.707271
# 1.0         actuated         12.579741      6.765486         64.835178
#             fixed_time       17.691810      8.256623         64.176650
#             multi_scale      10.702586      6.695023         52.090358

# %%
focus_col_list = ['waiting_time', 'queue_length', 'fuel_consumption']
df_avg = plots.rel_percent_by_fixed_time(df_focus_uw_normal, focus_col_list, ['ped_phasing', 'penetration'])
plots.plot_matrix(df_avg, focus_col_list, 'penetration', percentage=True, export=True, filename='maxtrix plot-UW intersection-percentage.png')
# Out:
# Matrix plot saved as Results\maxtrix plot-UW intersection-percentage.png
